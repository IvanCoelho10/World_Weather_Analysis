# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 628

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c3cadc6efe33ff89b13b6309439d9594

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
list(enumerate(cities))[0:10]
# Out:
# [(0, 'bredasdorp'),
#  (1, 'punta arenas'),
#  (2, 'busselton'),
#  (3, 'rikitea'),
#  (4, 'williston'),
#  (5, 'hermanus'),
#  (6, 'vao'),
#  (7, 'bereda'),
#  (8, 'ponta delgada'),
#  (9, 'chute-aux-outardes')]

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in list(enumerate(cities))[:]:

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description":city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | bredasdorp
# Processing Record 2 of Set 13 | punta arenas
# Processing Record 3 of Set 13 | busselton
# Processing Record 4 of Set 13 | rikitea
# Processing Record 5 of Set 13 | williston
# Processing Record 6 of Set 13 | hermanus
# Processing Record 7 of Set 13 | vao
# Processing Record 8 of Set 13 | bereda
# Processing Record 9 of Set 13 | ponta delgada
# Processing Record 10 of Set 13 | chute-aux-outardes
# Processing Record 11 of Set 13 | colares
# Processing Record 12 of Set 13 | qaanaaq
# Processing Record 13 of Set 13 | homer
# Processing Record 14 of Set 13 | avarua
# Processing Record 15 of Set 13 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 13 | vila franca do campo
# Processing Record 17 of Set 13 | estevan
# Processing Record 18 of Set 13 | yar-sale
# Processing Record 19 of Set 13 | ukiah
# Processing Record 20 of Set 13 | grand gaube
# Processing Record 21 of Set 13 | san patricio
# Processing Record 22 of Set 13 | kavaratti
# Processing Record 23 of Set 13 | hobart
# Processing Record 24 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 13 | new norfolk
# Processing Record 26 of Set 13 | ushuaia
# Processing Record 27 of Set 13 | alamosa
# Processing Record 28 of Set 13 | marrakesh
# Processing Record 29 of Set 13 | naustdal
# Processing Record 30 of Set 13 | barrow
# Processing Record 31 of Set 13 | ola
# Processing Record 32 of Set 13 | kodiak
# Processing Record 33 of Set 13 | gat
# Processing Record 34 of Set 13 | albany
# Processing Record 35 of Set 13 | bria
# Processing Record 36 of Set 13 | susanville
# Processing Record 37 of Set 13 | eureka
# Processing Record 38 of Set 13 | shelburne
# Processing Record 39 of Set 13 | garissa
# Processing Record 40 of Set 13 | verkhnevilyuysk
# Processing Record 41 of Set 13 | yellowknife
# Processing Record 42 of Set 13 | lorengau
# Processing Record 43 of Set 13 | bluff
# Processing Record 44 of Set 13 | nikolskoye
# Processing Record 45 of Set 13 | codrington
# Processing Record 46 of Set 13 | carnarvon
# Processing Record 47 of Set 13 | vestmannaeyjar
# Processing Record 48 of Set 13 | talnakh
# Processing Record 49 of Set 13 | salalah
# Processing Record 50 of Set 13 | cape town
# Processing Record 1 of Set 14 | khatanga
# Processing Record 2 of Set 14 | waingapu
# Processing Record 3 of Set 14 | khandyga
# Processing Record 4 of Set 14 | vanimo
# Processing Record 5 of Set 14 | akcakoca
# Processing Record 6 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 14 | dongsheng
# Processing Record 8 of Set 14 | dikson
# Processing Record 9 of Set 14 | pandan
# Processing Record 10 of Set 14 | agadir
# Processing Record 11 of Set 14 | tuktoyaktuk
# Processing Record 12 of Set 14 | waipawa
# Processing Record 13 of Set 14 | ballina
# Processing Record 14 of Set 14 | kapaa
# Processing Record 15 of Set 14 | nandaime
# Processing Record 16 of Set 14 | kaitangata
# Processing Record 17 of Set 14 | yazd
# Processing Record 18 of Set 14 | nanortalik
# Processing Record 19 of Set 14 | san fernando
# Processing Record 20 of Set 14 | tuatapere
# Processing Record 21 of Set 14 | mahebourg
# Processing Record 22 of Set 14 | wamba
# Processing Record 23 of Set 14 | thompson
# Processing Record 24 of Set 14 | miraflores
# Processing Record 25 of Set 14 | torbay
# Processing Record 26 of Set 14 | maldonado
# Processing Record 27 of Set 14 | saint george
# Processing Record 28 of Set 14 | narsaq
# Processing Record 29 of Set 14 | murray
# Processing Record 30 of Set 14 | mozarlandia
# Processing Record 31 of Set 14 | pevek
# Processing Record 32 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 33 of Set 14 | the valley
# Processing Record 34 of Set 14 | savinka
# Processing Record 35 of Set 14 | pangoa
# Processing Record 36 of Set 14 | ronneby
# Processing Record 37 of Set 14 | jacareacanga
# Processing Record 38 of Set 14 | kununurra
# Processing Record 39 of Set 14 | sur
# Processing Record 40 of Set 14 | tasiilaq
# Processing Record 41 of Set 14 | robertsport
# Processing Record 42 of Set 14 | jamestown
# Processing Record 43 of Set 14 | qui nhon
# Processing Record 44 of Set 14 | ilulissat
# Processing Record 45 of Set 14 | saskylakh
# Processing Record 46 of Set 14 | rocha
# Processing Record 47 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 14 | poronaysk
# Processing Record 49 of Set 14 | sampit
# Processing Record 50 of Set 14 | east london
# Processing Record 1 of Set 15 | klaksvik
# Processing Record 2 of Set 15 | ostrovnoy
# Processing Record 3 of Set 15 | vaini
# Processing Record 4 of Set 15 | hilo
# Processing Record 5 of Set 15 | taoudenni
# Processing Record 6 of Set 15 | anchorage
# Processing Record 7 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 15 | kupang
# Processing Record 9 of Set 15 | fortuna
# Processing Record 10 of Set 15 | carutapera
# Processing Record 11 of Set 15 | atuona
# Processing Record 12 of Set 15 | nador
# Processing Record 13 of Set 15 | biak
# Processing Record 14 of Set 15 | tefe
# Processing Record 15 of Set 15 | mataura
# Processing Record 16 of Set 15 | georgetown
# Processing Record 17 of Set 15 | dubuque
# Processing Record 18 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 15 | luderitz
# Processing Record 20 of Set 15 | tagab
# Processing Record 21 of Set 15 | kahului
# Processing Record 22 of Set 15 | souillac
# Processing Record 23 of Set 15 | iqaluit
# Processing Record 24 of Set 15 | richards bay
# Processing Record 25 of Set 15 | cabo san lucas
# Processing Record 26 of Set 15 | provideniya
# Processing Record 27 of Set 15 | awka
# Processing Record 28 of Set 15 | rundu
# Processing Record 29 of Set 15 | ponta do sol
# Processing Record 30 of Set 15 | chokurdakh
# Processing Record 31 of Set 15 | oudtshoorn
# Processing Record 32 of Set 15 | arraial do cabo
# Processing Record 33 of Set 15 | tazovskiy
# Processing Record 34 of Set 15 | karratha
# Processing Record 35 of Set 15 | airai
# Processing Record 36 of Set 15 | dembi dolo
# Processing Record 37 of Set 15 | poya
# Processing Record 38 of Set 15 | mayo
# Processing Record 39 of Set 15 | akureyri
# Processing Record 40 of Set 15 | buraydah
# Processing Record 41 of Set 15 | stepnogorsk
# Processing Record 42 of Set 15 | lagoa
# Processing Record 43 of Set 15 | kudahuvadhoo
# Processing Record 44 of Set 15 | longyearbyen
# Processing Record 45 of Set 15 | dargaville
# Processing Record 46 of Set 15 | wukari
# Processing Record 47 of Set 15 | marfino
# Processing Record 48 of Set 15 | glenluce
# Processing Record 49 of Set 15 | leiyang
# Processing Record 50 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 1 of Set 16 | xushan
# Processing Record 2 of Set 16 | leningradskiy
# Processing Record 3 of Set 16 | mount isa
# Processing Record 4 of Set 16 | esparta
# Processing Record 5 of Set 16 | san andres
# Processing Record 6 of Set 16 | dossor
# Processing Record 7 of Set 16 | salinopolis
# Processing Record 8 of Set 16 | naro
# Processing Record 9 of Set 16 | milkovo
# Processing Record 10 of Set 16 | dawlatabad
# Processing Record 11 of Set 16 | savona
# Processing Record 12 of Set 16 | altamont
# Processing Record 13 of Set 16 | ribeira grande
# Processing Record 14 of Set 16 | fairbanks
# Processing Record 15 of Set 16 | mayor pablo lagerenza
# Processing Record 16 of Set 16 | saint anthony
# Processing Record 17 of Set 16 | arlit
# Processing Record 18 of Set 16 | moree
# Processing Record 19 of Set 16 | baguanos
# Processing Record 20 of Set 16 | muli
# Processing Record 21 of Set 16 | mumford
# Processing Record 22 of Set 16 | bershet
# Processing Record 23 of Set 16 | lavrentiya
# Processing Record 24 of Set 16 | maturin
# Processing Record 25 of Set 16 | kokemaki
# Processing Record 26 of Set 16 | kalengwa
# Processing Record 27 of Set 16 | sao joao da barra
# Processing Record 28 of Set 16 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 16 | dalaba
# Processing Record 30 of Set 16 | salamiyah
# Processing Record 31 of Set 16 | tilichiki
# Processing Record 32 of Set 16 | palapye
# Processing Record 33 of Set 16 | constitucion
# Processing Record 34 of Set 16 | altay
# Processing Record 35 of Set 16 | maniitsoq
# Processing Record 36 of Set 16 | mogadishu
# Processing Record 37 of Set 16 | esperance
# Processing Record 38 of Set 16 | clyde river
# Processing Record 39 of Set 16 | el tigre
# Processing Record 40 of Set 16 | disraeli
# Processing Record 41 of Set 16 | vila velha
# Processing Record 42 of Set 16 | alta
# Processing Record 43 of Set 16 | nemuro
# Processing Record 44 of Set 16 | ahipara
# Processing Record 45 of Set 16 | grindavik
# Processing Record 46 of Set 16 | paradise valley
# Processing Record 47 of Set 16 | upernavik
# Processing Record 48 of Set 16 | coruripe
# Processing Record 49 of Set 16 | lebu
# Processing Record 50 of Set 16 | roald
# Processing Record 1 of Set 17 | humberto de campos
# Processing Record 2 of Set 17 | kismayo
# Processing Record 3 of Set 17 | springfield
# Processing Record 4 of Set 17 | faanui
# Processing Record 5 of Set 17 | chuy
# Processing Record 6 of Set 17 | druzhba
# Processing Record 7 of Set 17 | sibiti
# Processing Record 8 of Set 17 | makakilo city
# Processing Record 9 of Set 17 | lasa
# Processing Record 10 of Set 17 | praia
# Processing Record 11 of Set 17 | tsurib
# Processing Record 12 of Set 17 | tiksi
# Processing Record 13 of Set 17 | corumba
# Processing Record 14 of Set 17 | namibe
# Processing Record 15 of Set 17 | misratah
# Processing Record 16 of Set 17 | ostrowiec swietokrzyski
# Processing Record 17 of Set 17 | honiara
# Processing Record 18 of Set 17 | plouzane
# Processing Record 19 of Set 17 | hasaki
# Processing Record 20 of Set 17 | tateyama
# Processing Record 21 of Set 17 | port moresby
# Processing Record 22 of Set 17 | sitka
# Processing Record 23 of Set 17 | zhezkazgan
# Processing Record 24 of Set 17 | port lincoln
# Processing Record 25 of Set 17 | nambucca heads
# Processing Record 26 of Set 17 | baracoa
# Processing Record 27 of Set 17 | palu
# Processing Record 28 of Set 17 | axim
# Processing Record 29 of Set 17 | gorontalo
# Processing Record 30 of Set 17 | aasiaat
# Processing Record 31 of Set 17 | madhogarh
# Processing Record 32 of Set 17 | kalmunai
# Processing Record 33 of Set 17 | sandpoint
# Processing Record 34 of Set 17 | yumen
# Processing Record 35 of Set 17 | galle
# Processing Record 36 of Set 17 | mar del plata
# Processing Record 37 of Set 17 | vostok
# Processing Record 38 of Set 17 | dunedin
# Processing Record 39 of Set 17 | seoul
# Processing Record 40 of Set 17 | cayenne
# Processing Record 41 of Set 17 | dingle
# Processing Record 42 of Set 17 | san matias
# Processing Record 43 of Set 17 | port alfred
# Processing Record 44 of Set 17 | norman wells
# Processing Record 45 of Set 17 | harrisonville
# Processing Record 46 of Set 17 | pacifica
# Processing Record 47 of Set 17 | baykit
# Processing Record 48 of Set 17 | tretten
# Processing Record 49 of Set 17 | hervey bay
# Processing Record 50 of Set 17 | trairi
# Processing Record 1 of Set 18 | mayumba
# Processing Record 2 of Set 18 | churapcha
# Processing Record 3 of Set 18 | college
# Processing Record 4 of Set 18 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 18 | san carlos
# Processing Record 6 of Set 18 | mwinilunga
# Processing Record 7 of Set 18 | isangel
# Processing Record 8 of Set 18 | macklin
# Processing Record 9 of Set 18 | omsukchan
# Processing Record 10 of Set 18 | huarmey
# Processing Record 11 of Set 18 | mudgee
# Processing Record 12 of Set 18 | sakakah
# Processing Record 13 of Set 18 | boffa
# Processing Record 14 of Set 18 | great bend
# Processing Record 15 of Set 18 | sumenep
# Processing Record 16 of Set 18 | bethel
# Processing Record 17 of Set 18 | emba
# Processing Record 18 of Set 18 | hambantota
# Processing Record 19 of Set 18 | deputatskiy
# Processing Record 20 of Set 18 | port hedland
# Processing Record 21 of Set 18 | nome
# Processing Record 22 of Set 18 | ouallam
# Processing Record 23 of Set 18 | champerico
# Processing Record 24 of Set 18 | estelle
# Processing Record 25 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 18 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 18 | butaritari
# Processing Record 28 of Set 18 | ahtopol
# Processing Record 29 of Set 18 | aguilas
# Processing Record 30 of Set 18 | bengkulu
# Processing Record 31 of Set 18 | loveland
# Processing Record 32 of Set 18 | samarai
# Processing Record 33 of Set 18 | humaita
# Processing Record 34 of Set 18 | the pas
# Processing Record 35 of Set 18 | katsuura
# Processing Record 36 of Set 18 | togur
# Processing Record 37 of Set 18 | caravelas
# Processing Record 38 of Set 18 | clarence town
# Processing Record 39 of Set 18 | williams lake
# Processing Record 40 of Set 18 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 18 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 18 | saint-michel-des-saints
# Processing Record 43 of Set 18 | saint-philippe
# Processing Record 44 of Set 18 | saint-pierre
# Processing Record 45 of Set 18 | puerto ayora
# Processing Record 46 of Set 18 | walvis bay
# Processing Record 47 of Set 18 | tarsus
# Processing Record 48 of Set 18 | uruana
# Processing Record 49 of Set 18 | aras
# Processing Record 50 of Set 18 | coquimbo
# Processing Record 1 of Set 19 | toamasina
# Processing Record 2 of Set 19 | herat
# Processing Record 3 of Set 19 | zhoucheng
# Processing Record 4 of Set 19 | hamilton
# Processing Record 5 of Set 19 | gisborne
# Processing Record 6 of Set 19 | najran
# Processing Record 7 of Set 19 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 19 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 19 | luanda
# Processing Record 10 of Set 19 | huaral
# Processing Record 11 of Set 19 | guerrero negro
# Processing Record 12 of Set 19 | rolim de moura
# City not found. Skipping...
# Processing Record 13 of Set 19 | colac
# Processing Record 14 of Set 19 | boguchany
# Processing Record 15 of Set 19 | kalaleh
# Processing Record 16 of Set 19 | kawana waters
# City not found. Skipping...
# Processing Record 17 of Set 19 | viedma
# Processing Record 18 of Set 19 | boulsa
# Processing Record 19 of Set 19 | vega de alatorre
# Processing Record 20 of Set 19 | sorong
# Processing Record 21 of Set 19 | castro
# Processing Record 22 of Set 19 | kavieng
# Processing Record 23 of Set 19 | husavik
# Processing Record 24 of Set 19 | khovu-aksy
# Processing Record 25 of Set 19 | bambous virieux
# Processing Record 26 of Set 19 | hamada
# Processing Record 27 of Set 19 | chadiza
# Processing Record 28 of Set 19 | leh
# Processing Record 29 of Set 19 | uroteppa
# City not found. Skipping...
# Processing Record 30 of Set 19 | naryan-mar
# Processing Record 31 of Set 19 | igrim
# Processing Record 32 of Set 19 | ahuimanu
# Processing Record 33 of Set 19 | victoria
# Processing Record 34 of Set 19 | san jeronimo
# Processing Record 35 of Set 19 | nelspruit
# Processing Record 36 of Set 19 | phan thiet
# Processing Record 37 of Set 19 | margate
# Processing Record 38 of Set 19 | praia da vitoria
# Processing Record 39 of Set 19 | haines junction
# Processing Record 40 of Set 19 | kjollefjord
# Processing Record 41 of Set 19 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 19 | san jose
# Processing Record 43 of Set 19 | roma
# Processing Record 44 of Set 19 | eenhana
# Processing Record 45 of Set 19 | tura
# Processing Record 46 of Set 19 | mailsi
# Processing Record 47 of Set 19 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 19 | komsomolskiy
# Processing Record 49 of Set 19 | bardiyah
# Processing Record 50 of Set 19 | inta
# Processing Record 1 of Set 20 | manggar
# Processing Record 2 of Set 20 | kalanguy
# Processing Record 3 of Set 20 | mae hong son
# Processing Record 4 of Set 20 | shimoda
# Processing Record 5 of Set 20 | yangambi
# Processing Record 6 of Set 20 | tigil
# Processing Record 7 of Set 20 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 20 | port elizabeth
# Processing Record 9 of Set 20 | lompoc
# Processing Record 10 of Set 20 | camalu
# Processing Record 11 of Set 20 | zhigansk
# Processing Record 12 of Set 20 | jumla
# Processing Record 13 of Set 20 | torrington
# Processing Record 14 of Set 20 | imbituba
# Processing Record 15 of Set 20 | norwich
# Processing Record 16 of Set 20 | kholodnyy
# Processing Record 17 of Set 20 | ulladulla
# Processing Record 18 of Set 20 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 20 | general roca
# Processing Record 20 of Set 20 | yulara
# Processing Record 21 of Set 20 | kloulklubed
# Processing Record 22 of Set 20 | rio cuarto
# Processing Record 23 of Set 20 | houma
# Processing Record 24 of Set 20 | san ramon
# Processing Record 25 of Set 20 | sioux lookout
# Processing Record 26 of Set 20 | farmington
# Processing Record 27 of Set 20 | hofn
# Processing Record 28 of Set 20 | chumikan
# Processing Record 29 of Set 20 | sile
# Processing Record 30 of Set 20 | linchuan
# City not found. Skipping...
# Processing Record 31 of Set 20 | mezen
# Processing Record 32 of Set 20 | miyako
# Processing Record 33 of Set 20 | manado
# Processing Record 34 of Set 20 | kushiro
# Processing Record 35 of Set 20 | quatre cocos
# Processing Record 36 of Set 20 | candido mendes
# Processing Record 37 of Set 20 | harper
# Processing Record 38 of Set 20 | cortez
# Processing Record 39 of Set 20 | tres arroyos
# Processing Record 40 of Set 20 | abha
# Processing Record 41 of Set 20 | gunnedah
# Processing Record 42 of Set 20 | prince rupert
# Processing Record 43 of Set 20 | tsagan aman
# Processing Record 44 of Set 20 | itoman
# Processing Record 45 of Set 20 | alice springs
# Processing Record 46 of Set 20 | sechura
# Processing Record 47 of Set 20 | rawson
# Processing Record 48 of Set 20 | sarmanovo
# Processing Record 49 of Set 20 | palembang
# Processing Record 50 of Set 20 | ayan
# Processing Record 1 of Set 21 | nizhnyaya tavda
# Processing Record 2 of Set 21 | okhotsk
# Processing Record 3 of Set 21 | ziway
# Processing Record 4 of Set 21 | jiazi
# Processing Record 5 of Set 21 | faya
# Processing Record 6 of Set 21 | imuris
# Processing Record 7 of Set 21 | moratuwa
# Processing Record 8 of Set 21 | muhos
# Processing Record 9 of Set 21 | coahuayana
# Processing Record 10 of Set 21 | katobu
# Processing Record 11 of Set 21 | san pedro
# Processing Record 12 of Set 21 | vurnary
# Processing Record 13 of Set 21 | bulawayo
# Processing Record 14 of Set 21 | olafsvik
# Processing Record 15 of Set 21 | eydhafushi
# Processing Record 16 of Set 21 | kabalo
# Processing Record 17 of Set 21 | port blair
# Processing Record 18 of Set 21 | marana
# Processing Record 19 of Set 21 | westport
# Processing Record 20 of Set 21 | boddam
# Processing Record 21 of Set 21 | baherden
# Processing Record 22 of Set 21 | sokoto
# Processing Record 23 of Set 21 | moron
# Processing Record 24 of Set 21 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 21 | burica
# City not found. Skipping...
# Processing Record 26 of Set 21 | visby
# Processing Record 27 of Set 21 | severo-kurilsk
# Processing Record 28 of Set 21 | sungaipenuh
# Processing Record 29 of Set 21 | cheyenne
# Processing Record 30 of Set 21 | rio gallegos
# Processing Record 31 of Set 21 | sao miguel do araguaia
# Processing Record 32 of Set 21 | gondanglegi
# Processing Record 33 of Set 21 | sangar
# Processing Record 34 of Set 21 | cherskiy
# Processing Record 35 of Set 21 | pinehurst
# Processing Record 36 of Set 21 | san diego de los banos
# Processing Record 37 of Set 21 | geraldton
# Processing Record 38 of Set 21 | port hawkesbury
# Processing Record 39 of Set 21 | marzuq
# Processing Record 40 of Set 21 | kaliua
# Processing Record 41 of Set 21 | qaqortoq
# Processing Record 42 of Set 21 | havre-saint-pierre
# Processing Record 43 of Set 21 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 21 | popondetta
# Processing Record 45 of Set 21 | tomatlan
# Processing Record 46 of Set 21 | southbridge
# Processing Record 47 of Set 21 | jerez
# Processing Record 48 of Set 21 | kijang
# Processing Record 49 of Set 21 | banda aceh
# Processing Record 50 of Set 21 | acapulco
# Processing Record 1 of Set 22 | christchurch
# Processing Record 2 of Set 22 | bathsheba
# Processing Record 3 of Set 22 | aykhal
# Processing Record 4 of Set 22 | cotonou
# Processing Record 5 of Set 22 | gangotri
# City not found. Skipping...
# Processing Record 6 of Set 22 | batagay
# Processing Record 7 of Set 22 | muzhi
# Processing Record 8 of Set 22 | canitas
# City not found. Skipping...
# Processing Record 9 of Set 22 | antalaha
# Processing Record 10 of Set 22 | kruisfontein
# Processing Record 11 of Set 22 | sweetwater
# Processing Record 12 of Set 22 | comodoro rivadavia
# Processing Record 13 of Set 22 | portland
# Processing Record 14 of Set 22 | bandarbeyla
# Processing Record 15 of Set 22 | sao filipe
# Processing Record 16 of Set 22 | hami
# Processing Record 17 of Set 22 | riyadh
# Processing Record 18 of Set 22 | payo
# Processing Record 19 of Set 22 | kiunga
# Processing Record 20 of Set 22 | te anau
# Processing Record 21 of Set 22 | howard springs
# Processing Record 22 of Set 22 | luganville
# Processing Record 23 of Set 22 | marathon
# Processing Record 24 of Set 22 | tacuarembo
# Processing Record 25 of Set 22 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 22 | surt
# Processing Record 27 of Set 22 | utete
# Processing Record 28 of Set 22 | mogadouro
# Processing Record 29 of Set 22 | ifanadiana
# Processing Record 30 of Set 22 | barbate
# Processing Record 31 of Set 22 | hirara
# Processing Record 32 of Set 22 | lufilufi
# Processing Record 33 of Set 22 | kahna nau
# Processing Record 34 of Set 22 | buin
# Processing Record 35 of Set 22 | paka
# Processing Record 36 of Set 22 | rio claro
# Processing Record 37 of Set 22 | general pico
# Processing Record 38 of Set 22 | lata
# Processing Record 39 of Set 22 | alofi
# Processing Record 40 of Set 22 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 22 | kilindoni
# Processing Record 42 of Set 22 | beira
# Processing Record 43 of Set 22 | casa grande
# Processing Record 44 of Set 22 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 22 | kattivakkam
# Processing Record 46 of Set 22 | rawlins
# Processing Record 47 of Set 22 | skovorodino
# Processing Record 48 of Set 22 | rockland
# Processing Record 49 of Set 22 | anadyr
# Processing Record 50 of Set 22 | meulaboh
# Processing Record 1 of Set 23 | gladstone
# Processing Record 2 of Set 23 | alamos
# Processing Record 3 of Set 23 | agva
# City not found. Skipping...
# Processing Record 4 of Set 23 | balsa
# Processing Record 5 of Set 23 | tabuk
# Processing Record 6 of Set 23 | itarema
# Processing Record 7 of Set 23 | terra roxa
# Processing Record 8 of Set 23 | aquiraz
# Processing Record 9 of Set 23 | gizo
# Processing Record 10 of Set 23 | ondorhaan
# City not found. Skipping...
# Processing Record 11 of Set 23 | rusape
# Processing Record 12 of Set 23 | abu dhabi
# Processing Record 13 of Set 23 | virtsu
# Processing Record 14 of Set 23 | dubbo
# Processing Record 15 of Set 23 | asau
# Processing Record 16 of Set 23 | san rafael del sur
# Processing Record 17 of Set 23 | ust-tsilma
# Processing Record 18 of Set 23 | townsville
# Processing Record 19 of Set 23 | guhagar
# Processing Record 20 of Set 23 | garmsar
# Processing Record 21 of Set 23 | guanhaes
# Processing Record 22 of Set 23 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 23 | stornoway
# Processing Record 24 of Set 23 | chapais
# Processing Record 25 of Set 23 | ketchikan
# Processing Record 26 of Set 23 | buala
# Processing Record 27 of Set 23 | floriano
# Processing Record 28 of Set 23 | thessalon
# Processing Record 29 of Set 23 | aktau
# Processing Record 30 of Set 23 | albemarle
# Processing Record 31 of Set 23 | tabou
# Processing Record 32 of Set 23 | yashkul
# Processing Record 33 of Set 23 | kuna
# Processing Record 34 of Set 23 | aklavik
# Processing Record 35 of Set 23 | mazatlan
# Processing Record 36 of Set 23 | mana
# Processing Record 37 of Set 23 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 23 | placido de castro
# Processing Record 39 of Set 23 | nhulunbuy
# Processing Record 40 of Set 23 | dhone
# Processing Record 41 of Set 23 | emerald
# Processing Record 42 of Set 23 | bull savanna
# Processing Record 43 of Set 23 | taksimo
# Processing Record 44 of Set 23 | pangnirtung
# Processing Record 45 of Set 23 | akdagmadeni
# Processing Record 46 of Set 23 | paamiut
# Processing Record 47 of Set 23 | coihaique
# Processing Record 48 of Set 23 | rotterdam
# Processing Record 49 of Set 23 | kalamata
# Processing Record 50 of Set 23 | polyarnyy
# Processing Record 1 of Set 24 | pacific grove
# Processing Record 2 of Set 24 | khorixas
# Processing Record 3 of Set 24 | lysyanka
# Processing Record 4 of Set 24 | ojinaga
# Processing Record 5 of Set 24 | namtsy
# Processing Record 6 of Set 24 | green river
# Processing Record 7 of Set 24 | bubaque
# Processing Record 8 of Set 24 | iquique
# Processing Record 9 of Set 24 | paso de carrasco
# Processing Record 10 of Set 24 | nabire
# Processing Record 11 of Set 24 | emmett
# Processing Record 12 of Set 24 | amazar
# Processing Record 13 of Set 24 | roura
# Processing Record 14 of Set 24 | labuhan
# Processing Record 15 of Set 24 | inverell
# Processing Record 16 of Set 24 | moss point
# Processing Record 17 of Set 24 | terrace
# Processing Record 18 of Set 24 | twentynine palms
# Processing Record 19 of Set 24 | rovaniemi
# Processing Record 20 of Set 24 | aswan
# Processing Record 21 of Set 24 | egvekinot
# Processing Record 22 of Set 24 | gondar
# Processing Record 23 of Set 24 | yanam
# Processing Record 24 of Set 24 | wagar
# Processing Record 25 of Set 24 | santa isabel do rio negro
# Processing Record 26 of Set 24 | saldanha
# Processing Record 27 of Set 24 | matay
# Processing Record 28 of Set 24 | artigas
# Processing Record 29 of Set 24 | minab
# Processing Record 30 of Set 24 | svetlaya
# Processing Record 31 of Set 24 | mogochin
# City not found. Skipping...
# Processing Record 32 of Set 24 | skjern
# Processing Record 33 of Set 24 | sao jose da coroa grande
# Processing Record 34 of Set 24 | port macquarie
# Processing Record 35 of Set 24 | muros
# Processing Record 36 of Set 24 | santa isabel
# Processing Record 37 of Set 24 | port-gentil
# Processing Record 38 of Set 24 | puerto madryn
# Processing Record 39 of Set 24 | ishigaki
# Processing Record 40 of Set 24 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 24 | ekhabi
# Processing Record 42 of Set 24 | acari
# Processing Record 43 of Set 24 | alihe
# Processing Record 44 of Set 24 | kathu
# Processing Record 45 of Set 24 | cap malheureux
# Processing Record 46 of Set 24 | maragogi
# Processing Record 47 of Set 24 | atbasar
# Processing Record 48 of Set 24 | krasnoarmeysk
# Processing Record 49 of Set 24 | birjand
# Processing Record 50 of Set 24 | tosya
# Processing Record 1 of Set 25 | inongo
# Processing Record 2 of Set 25 | alzey
# Processing Record 3 of Set 25 | balimo
# City not found. Skipping...
# Processing Record 4 of Set 25 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 25 | rongcheng
# Processing Record 6 of Set 25 | jawhar
# Processing Record 7 of Set 25 | necochea
# Processing Record 8 of Set 25 | bilma
# Processing Record 9 of Set 25 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 25 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 25 | garautha
# Processing Record 12 of Set 25 | barcelos
# Processing Record 13 of Set 25 | chicla
# Processing Record 14 of Set 25 | tignere
# Processing Record 15 of Set 25 | bosaso
# Processing Record 16 of Set 25 | mandleshwar
# Processing Record 17 of Set 25 | ginda
# Processing Record 18 of Set 25 | la ronge
# Processing Record 19 of Set 25 | lannion
# Processing Record 20 of Set 25 | lodja
# Processing Record 21 of Set 25 | utiroa
# City not found. Skipping...
# Processing Record 22 of Set 25 | ellensburg
# Processing Record 23 of Set 25 | alyangula
# Processing Record 24 of Set 25 | san cristobal
# Processing Record 25 of Set 25 | bakchar
# Processing Record 26 of Set 25 | north bend
# Processing Record 27 of Set 25 | karasuk
# Processing Record 28 of Set 25 | northport
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bredasdorp -34.5322   20.0403     61.29        87          70
# 1        Punta Arenas -53.1500  -70.9167     51.91        37          20
# 2           Busselton -33.6500  115.3333     55.09        73          96
# 3             Rikitea -23.1203 -134.9692     74.62        80          97
# 4           Williston  48.1470 -103.6180     69.21        32           0
# 5            Hermanus -34.4187   19.2345     65.89        67          98
# 6                 Vao -22.6667  167.4833     69.78        63           3
# 7              Bereda  43.2686   -7.5406     58.91        99           9
# 8       Ponta Delgada  37.7333  -25.6667     70.52        88          75
# 9  Chute-Aux-Outardes  49.1168  -68.3990     54.41        82          20
#
#    Wind Speed Country                 Date      Description
# 0        3.44      ZA  2021-10-10 21:23:07    broken clouds
# 1       31.07      CL  2021-10-10 21:20:22       few clouds
# 2       15.12      AU  2021-10-10 21:23:18  overcast clouds
# 3       19.73      PF  2021-10-10 21:18:17  overcast clouds
# 4        5.99      US  2021-10-10 21:21:04        clear sky
# 5        7.85      ZA  2021-10-10 21:21:59  overcast clouds
# 6       13.06      NC  2021-10-10 21:23:26        clear sky
# 7        6.08      ES  2021-10-10 21:24:26        clear sky
# 8       12.66      PT  2021-10-10 21:24:27    broken clouds
# 9        5.75      CA  2021-10-10 21:24:27       few clouds

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0       Bredasdorp      ZA  2021-10-10 21:23:07 -34.5322   20.0403     61.29
# 1     Punta Arenas      CL  2021-10-10 21:20:22 -53.1500  -70.9167     51.91
# 2        Busselton      AU  2021-10-10 21:23:18 -33.6500  115.3333     55.09
# 3          Rikitea      PF  2021-10-10 21:18:17 -23.1203 -134.9692     74.62
# 4        Williston      US  2021-10-10 21:21:04  48.1470 -103.6180     69.21
# ..             ...     ...                  ...      ...       ...       ...
# 580  San Cristobal      VE  2021-10-10 21:23:37   7.7669  -72.2250     80.78
# 581        Bakchar      RU  2021-10-10 21:26:37  57.0186   82.0711     26.53
# 582     North Bend      US  2021-10-10 21:25:56  43.4065 -124.2243     61.25
# 583        Karasuk      RU  2021-10-10 21:26:38  53.7377   78.0403     38.79
# 584      Northport      US  2021-10-10 21:26:38  33.2290  -87.5772     84.69
#
#      Humidity  Cloudiness  Wind Speed      Description
# 0          87          70        3.44    broken clouds
# 1          37          20       31.07       few clouds
# 2          73          96       15.12  overcast clouds
# 3          80          97       19.73  overcast clouds
# 4          32           0        5.99        clear sky
# ..        ...         ...         ...              ...
# 580        93          86        2.93    moderate rain
# 581        81          98        3.65  overcast clouds
# 582        82          20       12.66       few clouds
# 583        95         100        7.76       light rain
# 584        62           1        8.05        clear sky
#
# [585 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13

# %%
city_data_df["Lat"] >= 0

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
